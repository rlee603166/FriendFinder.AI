# %%
from sklearn.datasets import fetch_lfw_pairs
import matplotlib.pyplot as plt

# %%
training_pairs = fetch_lfw_pairs(subset='train', resize=0.42).pairs

# %%
plt.imshow(training_pairs[0][0])

# %%
plt.imshow(training_pairs[0][1])
